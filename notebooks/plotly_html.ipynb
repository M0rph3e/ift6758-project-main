# %% [markdown]
# # Interactive Figures with Plotly
#
# This demo has been taken from the [official Plotly docs](https://plotly.com/python/dropdowns/), showcasing how to create interactive plots with dropdown menus.
# In addition, this will also show you how to export these plots into an HTML format which can then directly be embedded into your blogpost!

# %%
# Ensure you have the required packages for this demo
# !pip install plotly pandas
# Out:
# Requirement already satisfied: plotly in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (5.3.1)
# Requirement already satisfied: pandas in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (1.3.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (from plotly) (1.16.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\saiak\.conda\envs\ift6758-conda-env\lib\site-packages (from pandas) (2.8.2)

# %%
# Import required packages
import plotly.graph_objects as go
import pandas as pd

# %%
# load dataset
df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/volcano.csv")

# create figure
fig = go.Figure()

# Add surface trace
fig.add_trace(go.Surface(z=df.values.tolist(), colorscale="Viridis"))

# Update plot sizing
fig.update_layout(
    width=800,
    height=900,
    autosize=False,
    margin=dict(t=0, b=0, l=0, r=0),
    template="plotly_white",
)

# Update 3D scene options
fig.update_scenes(
    aspectratio=dict(x=1, y=1, z=0.7),
    aspectmode="manual"
)

# Add dropdown
fig.update_layout(
    updatemenus=[
        dict(
            buttons=list([
                dict(
                    args=["type", "surface"],
                    label="3D Surface",
                    method="restyle"
                ),
                dict(
                    args=["type", "heatmap"],
                    label="Heatmap",
                    method="restyle"
                )
            ]),
            direction="down",
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.1,
            xanchor="left",
            y=1.1,
            yanchor="top"
        ),
    ]
)

# Add annotation
fig.update_layout(
    annotations=[
        dict(text="Trace type:", showarrow=False,
        x=0, y=1.085, yref="paper", align="left")
    ]
)

fig.show()

# %%
# Export the figure to an HTML format
fig.write_html("plotly_demo_2.html")
