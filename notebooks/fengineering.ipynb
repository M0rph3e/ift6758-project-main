# %% [markdown]
# ## Feature Engineering

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np

def angle(gp, p):
    """
        gp - goal coordinates
        p- puck coordinates
        angle in radians
    """
    if gp[0] > 0:
        vector = (gp[0] - p[0])+((gp[1]-p[1])*1j)
        angle = np.angle(vector)
    else:
        vector = (p[0]-gp[0])+((p[1]-gp[1])*1j)
        angle = np.angle(vector)
    return angle

def distance(gp, p):
    """
        gp - goal coordinates
        p- puck coordinates
    """
    distance = np.sqrt((gp[0] - p[0])**2 + (gp[1] - p[1])**2)
    return distance

a = (-89, 0)
b = (-89, -15)
print(angle(a, b))
print(distance(a,b))
# Out:
# -1.5707963267948966
# 15.0

# %% [markdown]
# ### Train DF (To be done for test DF as well)

# %%
from  ift6758.data.data_acquisition import Season
import pandas as pd

# %%
train_years = [2015,2016,2017,2018]
seasons= []
periods=[]
for yr in train_years:
    season = Season(yr,"../ift6758/data")
    df_season = season.clean_data()
    df_period = season.periodInfo()
    seasons.append(df_season)
    periods.append(df_period)
# Out:
# File already Exists, loading from ../ift6758/data/PICKLE//2015_clean.pkl
# File already Exists, loading from ../ift6758/data/PICKLE//2015.pkl
# Len of games_list in 2015 is 1325
# File already Exists, loading from ../ift6758/data/PICKLE//2016_clean.pkl
# File already Exists, loading from ../ift6758/data/PICKLE//2016.pkl
# Len of games_list in 2016 is 1332
# File already Exists, loading from ../ift6758/data/PICKLE//2017_clean.pkl
# File already Exists, loading from ../ift6758/data/PICKLE//2017.pkl
# Len of games_list in 2017 is 1376
# File already Exists, loading from ../ift6758/data/PICKLE//2018_clean.pkl
# File already Exists, loading from ../ift6758/data/PICKLE//2018.pkl
# Len of games_list in 2018 is 1376

# %%
df_seasons = pd.concat(seasons).reset_index(drop=True)
df_periods = pd.concat(periods).reset_index(drop=True)

# %%
df_seasons.head()
# Out:
#   result.event      gamePk            team.name  about.period  \
# 0         Shot  2015020001  Toronto Maple Leafs             1
# 1         Shot  2015020001  Toronto Maple Leafs             1
# 2         Shot  2015020001  Toronto Maple Leafs             1
# 3         Shot  2015020001  Toronto Maple Leafs             1
# 4         Shot  2015020001  Toronto Maple Leafs             1
#
#   about.periodTime about.periodType about.periodTimeRemaining  coordinates.x  \
# 0            00:51          REGULAR                     19:09          -55.0
# 1            01:05          REGULAR                     18:55          -79.0
# 2            01:06          REGULAR                     18:54          -75.0
# 3            01:53          REGULAR                     18:07          -55.0
# 4            02:37          REGULAR                     17:23          -61.0
#
#    coordinates.y result.secondaryType result.emptyNet result.strength.name  \
# 0            6.0           Wrist Shot             NaN                  NaN
# 1            0.0            Snap Shot             NaN                  NaN
# 2           -1.0            Snap Shot             NaN                  NaN
# 3          -36.0           Wrist Shot             NaN                  NaN
# 4           -1.0               Tip-In             NaN                  NaN
#
#          shooter       goalie
# 0     Brad Boyes  Carey Price
# 1    Nazem Kadri  Carey Price
# 2    Nazem Kadri  Carey Price
# 3  Daniel Winnik  Carey Price
# 4  Joffrey Lupul  Carey Price

# %%
df_periods.head()
# Out:
#   periodType             startTime               endTime  num ordinalNum  \
# 0    REGULAR  2015-10-07T23:20:43Z  2015-10-08T00:00:58Z    1        1st
# 1    REGULAR  2015-10-08T00:19:18Z  2015-10-08T01:00:15Z    2        2nd
# 2    REGULAR  2015-10-08T01:18:42Z  2015-10-08T01:56:34Z    3        3rd
# 3    REGULAR  2015-10-08T00:32:37Z  2015-10-08T01:06:34Z    1        1st
# 4    REGULAR  2015-10-08T01:25:05Z  2015-10-08T02:00:48Z    2        2nd
#
#    goals  shotsOnGoal rinkSide      gamePk             teamname  isHomeTeam  \
# 0      0           11    right  2015020001  Toronto Maple Leafs        True
# 1      1           16     left  2015020001  Toronto Maple Leafs        True
# 2      0           10    right  2015020001  Toronto Maple Leafs        True
# 3      1           12    right  2015020002   Chicago Blackhawks        True
# 4      1            8     left  2015020002   Chicago Blackhawks        True
#
#   goalCoordinates
# 0        (-89, 0)
# 1         (89, 0)
# 2        (-89, 0)
# 3        (-89, 0)
# 4         (89, 0)

# %%
map_columns = {"periodType": "about.periodType", "num": "about.period","teamname":"team.name" }
df_periods_to_join = df_periods[list(map_columns.keys())+["gamePk","goalCoordinates"]].rename(columns=map_columns)
df_periods_to_join.head()
# Out:
#   about.periodType  about.period            team.name      gamePk  \
# 0          REGULAR             1  Toronto Maple Leafs  2015020001
# 1          REGULAR             2  Toronto Maple Leafs  2015020001
# 2          REGULAR             3  Toronto Maple Leafs  2015020001
# 3          REGULAR             1   Chicago Blackhawks  2015020002
# 4          REGULAR             2   Chicago Blackhawks  2015020002
#
#   goalCoordinates
# 0        (-89, 0)
# 1         (89, 0)
# 2        (-89, 0)
# 3        (-89, 0)
# 4         (89, 0)

# %%
df_seasons_periods = df_seasons.merge(df_periods_to_join, how='left',on=["about.periodType","about.period","team.name","gamePk"])

# %%
# merged = df_seasons.merge(df_periods_to_join, indicator=True, how='outer')
# merged[merged['_merge'] == 'right_only'] # <-- Indicated no shot are taken by the team in that period/

# %%
# merged[merged['_merge'] == 'left_only']# <-- Indicated all are shootouts not captured in line score of JSON

# %% [markdown]
# ### Corection of Coordinates for shootout

# %%
def correctionCoordinates(r):
    if isinstance(r["goalCoordinates"], tuple):
        return r["goalCoordinates"]
    else:
        if r["coordinates.x"]>0:
            return (89,0)
        else:
            return (-89,0)
df_seasons_periods["goalCoordinates"] = df_seasons_periods.apply(lambda r: correctionCoordinates(r),axis=1)

# %%
df_seasons_periods.head()
# Out:
#   result.event      gamePk            team.name  about.period  \
# 0         Shot  2015020001  Toronto Maple Leafs             1
# 1         Shot  2015020001  Toronto Maple Leafs             1
# 2         Shot  2015020001  Toronto Maple Leafs             1
# 3         Shot  2015020001  Toronto Maple Leafs             1
# 4         Shot  2015020001  Toronto Maple Leafs             1
#
#   about.periodTime about.periodType about.periodTimeRemaining  coordinates.x  \
# 0            00:51          REGULAR                     19:09          -55.0
# 1            01:05          REGULAR                     18:55          -79.0
# 2            01:06          REGULAR                     18:54          -75.0
# 3            01:53          REGULAR                     18:07          -55.0
# 4            02:37          REGULAR                     17:23          -61.0
#
#    coordinates.y result.secondaryType result.emptyNet result.strength.name  \
# 0            6.0           Wrist Shot             NaN                  NaN
# 1            0.0            Snap Shot             NaN                  NaN
# 2           -1.0            Snap Shot             NaN                  NaN
# 3          -36.0           Wrist Shot             NaN                  NaN
# 4           -1.0               Tip-In             NaN                  NaN
#
#          shooter       goalie goalCoordinates
# 0     Brad Boyes  Carey Price        (-89, 0)
# 1    Nazem Kadri  Carey Price        (-89, 0)
# 2    Nazem Kadri  Carey Price        (-89, 0)
# 3  Daniel Winnik  Carey Price        (-89, 0)
# 4  Joffrey Lupul  Carey Price        (-89, 0)

# %% [markdown]
# ### Empty Net nans as 0

# %%
df_seasons_periods["result.emptyNet"] = df_seasons_periods["result.emptyNet"].fillna(0)
df_seasons_periods.head()
# Out:
#   result.event      gamePk            team.name  about.period  \
# 0         Shot  2015020001  Toronto Maple Leafs             1
# 1         Shot  2015020001  Toronto Maple Leafs             1
# 2         Shot  2015020001  Toronto Maple Leafs             1
# 3         Shot  2015020001  Toronto Maple Leafs             1
# 4         Shot  2015020001  Toronto Maple Leafs             1
#
#   about.periodTime about.periodType about.periodTimeRemaining  coordinates.x  \
# 0            00:51          REGULAR                     19:09          -55.0
# 1            01:05          REGULAR                     18:55          -79.0
# 2            01:06          REGULAR                     18:54          -75.0
# 3            01:53          REGULAR                     18:07          -55.0
# 4            02:37          REGULAR                     17:23          -61.0
#
#    coordinates.y result.secondaryType result.emptyNet result.strength.name  \
# 0            6.0           Wrist Shot               0                  NaN
# 1            0.0            Snap Shot               0                  NaN
# 2           -1.0            Snap Shot               0                  NaN
# 3          -36.0           Wrist Shot               0                  NaN
# 4           -1.0               Tip-In               0                  NaN
#
#          shooter       goalie goalCoordinates
# 0     Brad Boyes  Carey Price        (-89, 0)
# 1    Nazem Kadri  Carey Price        (-89, 0)
# 2    Nazem Kadri  Carey Price        (-89, 0)
# 3  Daniel Winnik  Carey Price        (-89, 0)
# 4  Joffrey Lupul  Carey Price        (-89, 0)

# %% [markdown]
# ### isGoal

# %%
df_seasons_periods["isGoal"] =df_seasons_periods[["result.event"]].apply(lambda r: 1 if (r["result.event"]=="Goal") else 0,axis=1)
df_seasons_periods.head()
    # lambda r : 1 (if r["result.event"]=="Goal") else 0,axis=1)
# Out:
#   result.event      gamePk            team.name  about.period  \
# 0         Shot  2015020001  Toronto Maple Leafs             1
# 1         Shot  2015020001  Toronto Maple Leafs             1
# 2         Shot  2015020001  Toronto Maple Leafs             1
# 3         Shot  2015020001  Toronto Maple Leafs             1
# 4         Shot  2015020001  Toronto Maple Leafs             1
#
#   about.periodTime about.periodType about.periodTimeRemaining  coordinates.x  \
# 0            00:51          REGULAR                     19:09          -55.0
# 1            01:05          REGULAR                     18:55          -79.0
# 2            01:06          REGULAR                     18:54          -75.0
# 3            01:53          REGULAR                     18:07          -55.0
# 4            02:37          REGULAR                     17:23          -61.0
#
#    coordinates.y result.secondaryType result.emptyNet result.strength.name  \
# 0            6.0           Wrist Shot               0                  NaN
# 1            0.0            Snap Shot               0                  NaN
# 2           -1.0            Snap Shot               0                  NaN
# 3          -36.0           Wrist Shot               0                  NaN
# 4           -1.0               Tip-In               0                  NaN
#
#          shooter       goalie goalCoordinates  isGoal
# 0     Brad Boyes  Carey Price        (-89, 0)       0
# 1    Nazem Kadri  Carey Price        (-89, 0)       0
# 2    Nazem Kadri  Carey Price        (-89, 0)       0
# 3  Daniel Winnik  Carey Price        (-89, 0)       0
# 4  Joffrey Lupul  Carey Price        (-89, 0)       0

# %% [markdown]
# ### Distance and Angle

# %%
df_seasons_periods["distanceNet"]= df_seasons_periods[['coordinates.x','coordinates.y','goalCoordinates']].apply(lambda r: distance(r["goalCoordinates"],(r["coordinates.x"],r["coordinates.y"])), axis=1)
df_seasons_periods["angleNet"]= df_seasons_periods[['coordinates.x','coordinates.y','goalCoordinates']].apply(lambda r: angle(r["goalCoordinates"],(r["coordinates.x"],r["coordinates.y"])), axis=1)

# %%
df_seasons_periods
# Out:
#        result.event      gamePk            team.name  about.period  \
# 0              Shot  2015020001  Toronto Maple Leafs             1
# 1              Shot  2015020001  Toronto Maple Leafs             1
# 2              Shot  2015020001  Toronto Maple Leafs             1
# 3              Shot  2015020001  Toronto Maple Leafs             1
# 4              Shot  2015020001  Toronto Maple Leafs             1
# ...             ...         ...                  ...           ...
# 332737         Goal  2018030417      St. Louis Blues             3
# 332738         Shot  2018030417      St. Louis Blues             3
# 332739         Shot  2018030417      St. Louis Blues             3
# 332740         Shot  2018030417        Boston Bruins             3
# 332741         Goal  2018030417        Boston Bruins             3
#
#        about.periodTime about.periodType about.periodTimeRemaining  \
# 0                 00:51          REGULAR                     19:09
# 1                 01:05          REGULAR                     18:55
# 2                 01:06          REGULAR                     18:54
# 3                 01:53          REGULAR                     18:07
# 4                 02:37          REGULAR                     17:23
# ...                 ...              ...                       ...
# 332737            15:22          REGULAR                     04:38
# 332738            15:51          REGULAR                     04:09
# 332739            15:55          REGULAR                     04:05
# 332740            16:50          REGULAR                     03:10
# 332741            17:50          REGULAR                     02:10
#
#         coordinates.x  coordinates.y result.secondaryType result.emptyNet  \
# 0               -55.0            6.0           Wrist Shot               0
# 1               -79.0            0.0            Snap Shot               0
# 2               -75.0           -1.0            Snap Shot               0
# 3               -55.0          -36.0           Wrist Shot               0
# 4               -61.0           -1.0               Tip-In               0
# ...               ...            ...                  ...             ...
# 332737          -77.0            7.0            Snap Shot           False
# 332738          -69.0            7.0            Snap Shot               0
# 332739          -65.0           -4.0            Snap Shot               0
# 332740           42.0            3.0           Wrist Shot               0
# 332741           44.0           24.0           Wrist Shot           False
#
#        result.strength.name           shooter             goalie  \
# 0                       NaN        Brad Boyes        Carey Price
# 1                       NaN       Nazem Kadri        Carey Price
# 2                       NaN       Nazem Kadri        Carey Price
# 3                       NaN     Daniel Winnik        Carey Price
# 4                       NaN     Joffrey Lupul        Carey Price
# ...                     ...               ...                ...
# 332737                 Even      Zach Sanford        Tuukka Rask
# 332738                  NaN   Alexander Steen        Tuukka Rask
# 332739                  NaN     Ryan O'Reilly        Tuukka Rask
# 332740                  NaN  Marcus Johansson  Jordan Binnington
# 332741                 Even     Matt Grzelcyk  Jordan Binnington
#
#        goalCoordinates  isGoal  distanceNet  angleNet
# 0             (-89, 0)       0    34.525353  0.174672
# 1             (-89, 0)       0    10.000000  0.000000
# 2             (-89, 0)       0    14.035669 -0.071307
# 3             (-89, 0)       0    49.517674 -0.813962
# 4             (-89, 0)       0    28.017851 -0.035699
# ...                ...     ...          ...       ...
# 332737        (-89, 0)       1    13.892444  0.528074
# 332738        (-89, 0)       0    21.189620  0.336675
# 332739        (-89, 0)       0    24.331050 -0.165149
# 332740         (89, 0)       0    47.095647 -0.063743
# 332741         (89, 0)       1    51.000000 -0.489957
#
# [332742 rows x 18 columns]
